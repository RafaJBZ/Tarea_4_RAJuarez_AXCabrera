# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFzQj91sOlkeDFkg5HDbjtR4QJYmLXkfMNig&usqp=CAU" width="400" height="500" />
#
#
# ### <font color='navy'> Modelos no lineales para pronósticos.
#
# **Nombres:** Axel Jaramillo, Rafael Juarez Badillo
#
# **Fecha:** 7 marzo 2024
#
# **Expediente** : 730793, 733240
#
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: [Link](https://github.com/RafaJBZ/Tarea_4_RAJuarez_AXCabrera)
#
# # Tarea 4: Clase 11

# %% [markdown]
# ## Descripción
# Terminar los demás numerales faltantes del ejercicio, dataset boston housing.

# %% [markdown]
# Código de solución estudiante 1

# %%
# Código de solución estudiante 1
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns


# Cargar los datos de entrenamiento y prueba
(train_data, train_labels), (test_data, test_labels) = keras.datasets.boston_housing.load_data()
# Out:
# 2024-03-07 16:15:34.641095: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-07 16:15:37.571332: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-07 16:15:37.571604: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-07 16:15:38.232488: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-07 16:15:40.027361: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-07 16:15:51.741370: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       5 import matplotlib.pyplot as plt
#       6 import pandas as pd
# ----> 7 import seaborn as sns
#      10 # Cargar los datos de entrenamiento y prueba
#      11 (train_data, train_labels), (test_data, test_labels) = keras.datasets.boston_housing.load_data()
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
train_data.shape, train_labels.shape, test_data.shape, test_labels.shape
# Out:
# ((404, 13), (404,), (102, 13), (102,))

# %%
# Obviar la columna -2 por que considera una variable de poco interés
np.delete(train_data, -2, axis=1)[0:3,-4:]
train_data = np.delete(train_data, -2, axis=1)
test_data = np.delete(test_data, -2, axis=1)
np.hstack([train_labels, test_labels]).shape
# Out:
# (506,)

# %%
# Analizar la data completa
columns = [
    'CRIM',
    'ZN',
    'INDUS',
    'CHAS',
    'NOX',
    'RM',
    'AGE',
    'DIS',
    'RAD',
    'TAX',
    'PTRATIO',
    'LSTAT',
    'MEDV',
]

X = np.vstack([train_data, test_data])
y = np.hstack([train_labels, test_labels]).reshape(-1, 1)
data = pd.DataFrame(np.concatenate((X, y), axis=1), columns=columns)
data.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0  1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1  0.02177  82.5   2.03   0.0  0.415  7.610   15.7  6.2700   2.0  348.0
# 2  4.89822   0.0  18.10   0.0  0.631  4.970  100.0  1.3325  24.0  666.0
# 3  0.03961   0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 4  3.69311   0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
# 5  0.28392   0.0   7.38   0.0  0.493  5.708   74.3  4.7211   5.0  287.0
# 6  9.18702   0.0  18.10   0.0  0.700  5.536  100.0  1.5804  24.0  666.0
# 7  4.09740   0.0  19.58   0.0  0.871  5.468  100.0  1.4118   5.0  403.0
# 8  2.15505   0.0  19.58   0.0  0.871  5.628  100.0  1.5166   5.0  403.0
# 9  1.62864   0.0  21.89   0.0  0.624  5.019  100.0  1.4394   4.0  437.0
#
#    PTRATIO  LSTAT  MEDV
# 0     21.0  18.72  15.2
# 1     14.7   3.11  42.3
# 2     20.2   3.26  50.0
# 3     20.2   8.01  21.1
# 4     20.2  14.65  17.7
# 5     19.6  11.74  18.5
# 6     20.2  23.60  11.3
# 7     14.7  26.42  15.6
# 8     14.7  16.65  15.6
# 9     21.2  34.41  14.4

# %%
X.shape, y.shape
# Out:
# ((506, 12), (506, 1))

# %% [markdown]
# ## Boston Dataset
# A data set containing housing values in 506 suburbs of Boston.
#
# crim: per capita crime rate by town.
#
# zn: proportion of residential land zoned for lots over 25,000 sq.ft.
#
# indus: proportion of non-retail business acres per town.
#
# chas: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
# nox: nitrogen oxides concentration (parts per 10 million).
#
# rm: average number of rooms per dwelling.
#
# age: proportion of owner-occupied units built prior to 1940.
#
# dis: weighted mean of distances to five Boston employment centres.
#
# rad: index of accessibility to radial highways.
#
# tax: full-value property-tax rate per $10,000.
#
# ptratio: pupil-teacher ratio by town.
#
# lstat: lower status of the population (percent).
#
# medv: median value of owner-occupied homes in $1000s.

# %%
sns.distplot(y)
plt.show()
# Out:
# <ipython-input-88-ddda3f7b3fdc>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y)

# %%
corr = data.corr()
fig, ax = plt.subplots(1,1, figsize=(10, 8))
sns.heatmap(corr, annot=True, ax=ax)
# Out:
# <Axes: >

# %%
# Elegir variables más significativas
data.head(1)
# Out:
#       CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0  1.23247  0.0   8.14   0.0  0.538  6.142  91.7  3.9769  4.0  307.0     21.0
#
#    LSTAT  MEDV  log_medv
# 0  18.72  15.2  2.721295

# %%
features = ['ZN', 'CHAS', 'RM', 'DIS']
output = ['MEDV']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
for column in features:
    data[column].plot()
    plt.title(f"Plot of {column}")
    plt.xlabel("Index")
    plt.ylabel(column)
    plt.show()

# %%
features_cols = ['RM', 'ZN', 'DIS', 'CHAS']
target_col = ['MEDV']


scaler = StandardScaler()
data_standardized = scaler.fit_transform(data[features_cols])


standarized = pd.DataFrame(data_standardized, columns=features_cols)

X_train, X_test, y_train, y_test = train_test_split(standarized, data[target_col], test_size=0.2, random_state=1234)


z_scores = (X_train - X_train.mean()) / X_train.std()
outliers = (z_scores > 3) | (z_scores < -3)
X_train_no_outliers = X_train[~outliers.any(axis=1)]
y_train_no_outliers = y_train[~outliers.any(axis=1)]

# %%
model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(X_train_no_outliers.shape[1],)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1)
])

# Compile the model
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# Train the model
fit = model.fit(X_train_no_outliers, y_train_no_outliers, epochs=100, batch_size=32, validation_split=0.2)

# Print model summary
model.summary()
# Out:
# Epoch 1/100
# 9/9 [==============================] - 2s 35ms/step - loss: 505.4037 - mae: 21.0121 - val_loss: 527.2896 - val_mae: 21.1514
# Epoch 2/100
# 9/9 [==============================] - 0s 7ms/step - loss: 455.6645 - mae: 19.8395 - val_loss: 464.4555 - val_mae: 19.6477
# Epoch 3/100
# 9/9 [==============================] - 0s 6ms/step - loss: 376.2712 - mae: 17.7799 - val_loss: 365.3759 - val_mae: 17.0078
# Epoch 4/100
# 9/9 [==============================] - 0s 9ms/step - loss: 266.5234 - mae: 14.5080 - val_loss: 245.6137 - val_mae: 13.4605
# Epoch 5/100
# 9/9 [==============================] - 0s 6ms/step - loss: 154.3346 - mae: 10.4724 - val_loss: 146.0038 - val_mae: 9.8780
# Epoch 6/100
# 9/9 [==============================] - 0s 8ms/step - loss: 82.4665 - mae: 7.5034 - val_loss: 93.8804 - val_mae: 7.9016
# Epoch 7/100
# 9/9 [==============================] - 0s 6ms/step - loss: 54.6998 - mae: 6.0809 - val_loss: 74.5599 - val_mae: 7.0583
# Epoch 8/100
# 9/9 [==============================] - 0s 6ms/step - loss: 46.2602 - mae: 5.5432 - val_loss: 64.5445 - val_mae: 6.4413
# Epoch 9/100
# 9/9 [==============================] - 0s 7ms/step - loss: 41.8076 - mae: 5.2412 - val_loss: 61.6363 - val_mae: 6.1643
# Epoch 10/100
# 9/9 [==============================] - 0s 6ms/step - loss: 38.9591 - mae: 4.9968 - val_loss: 59.8877 - val_mae: 5.9695
# Epoch 11/100
# 9/9 [==============================] - 0s 8ms/step - loss: 36.7941 - mae: 4.8048 - val_loss: 58.5933 - val_mae: 5.8292
# Epoch 12/100
# 9/9 [==============================] - 0s 8ms/step - loss: 35.8800 - mae: 4.6681 - val_loss: 58.5154 - val_mae: 5.7708
# Epoch 13/100
# 9/9 [==============================] - 0s 7ms/step - loss: 34.3057 - mae: 4.5681 - val_loss: 57.4931 - val_mae: 5.6805
# Epoch 14/100
# 9/9 [==============================] - 0s 7ms/step - loss: 33.3537 - mae: 4.4743 - val_loss: 53.3752 - val_mae: 5.3970
# Epoch 15/100
# 9/9 [==============================] - 0s 6ms/step - loss: 31.4868 - mae: 4.3315 - val_loss: 48.4417 - val_mae: 5.0152
# Epoch 16/100
# 9/9 [==============================] - 0s 8ms/step - loss: 31.1922 - mae: 4.2997 - val_loss: 52.6610 - val_mae: 5.2875
# Epoch 17/100
# 9/9 [==============================] - 0s 8ms/step - loss: 30.3385 - mae: 4.2115 - val_loss: 50.9835 - val_mae: 5.1557
# Epoch 18/100
# 9/9 [==============================] - 0s 7ms/step - loss: 29.6399 - mae: 4.1478 - val_loss: 48.8554 - val_mae: 4.9944
# Epoch 19/100
# 9/9 [==============================] - 0s 8ms/step - loss: 28.8141 - mae: 4.0845 - val_loss: 53.7635 - val_mae: 5.3134
# Epoch 20/100
# 9/9 [==============================] - 0s 6ms/step - loss: 29.6441 - mae: 4.1430 - val_loss: 53.6007 - val_mae: 5.2765
# Epoch 21/100
# 9/9 [==============================] - 0s 8ms/step - loss: 27.6978 - mae: 3.9916 - val_loss: 46.7485 - val_mae: 4.7143
# Epoch 22/100
# 9/9 [==============================] - 0s 7ms/step - loss: 27.5995 - mae: 3.9459 - val_loss: 47.9862 - val_mae: 4.8223
# Epoch 23/100
# 9/9 [==============================] - 0s 6ms/step - loss: 27.6472 - mae: 3.9587 - val_loss: 48.3662 - val_mae: 4.8270
# Epoch 24/100
# 9/9 [==============================] - 0s 7ms/step - loss: 27.3313 - mae: 3.9299 - val_loss: 52.8540 - val_mae: 5.1469
# Epoch 25/100
# 9/9 [==============================] - 0s 9ms/step - loss: 26.2684 - mae: 3.8294 - val_loss: 54.4052 - val_mae: 5.2322
# Epoch 26/100
# 9/9 [==============================] - 0s 8ms/step - loss: 26.7832 - mae: 3.8819 - val_loss: 50.6766 - val_mae: 4.9646
# Epoch 27/100
# 9/9 [==============================] - 0s 9ms/step - loss: 25.7192 - mae: 3.7599 - val_loss: 49.7700 - val_mae: 4.8797
# Epoch 28/100
# 9/9 [==============================] - 0s 11ms/step - loss: 25.6595 - mae: 3.7303 - val_loss: 52.9588 - val_mae: 5.1002
# Epoch 29/100
# 9/9 [==============================] - 0s 11ms/step - loss: 25.6207 - mae: 3.7032 - val_loss: 50.3094 - val_mae: 4.8923
# Epoch 30/100
# 9/9 [==============================] - 0s 13ms/step - loss: 25.1997 - mae: 3.6824 - val_loss: 48.3580 - val_mae: 4.7258
# Epoch 31/100
# 9/9 [==============================] - 0s 15ms/step - loss: 24.5443 - mae: 3.6021 - val_loss: 48.5861 - val_mae: 4.7281
# Epoch 32/100
# 9/9 [==============================] - 0s 10ms/step - loss: 24.6050 - mae: 3.5985 - val_loss: 49.0329 - val_mae: 4.7230
# Epoch 33/100
# 9/9 [==============================] - 0s 12ms/step - loss: 24.5165 - mae: 3.5845 - val_loss: 50.6017 - val_mae: 4.8850
# Epoch 34/100
# 9/9 [==============================] - 0s 11ms/step - loss: 23.9904 - mae: 3.5344 - val_loss: 46.7315 - val_mae: 4.5219
# Epoch 35/100
# 9/9 [==============================] - 0s 15ms/step - loss: 23.2076 - mae: 3.5217 - val_loss: 50.1478 - val_mae: 4.7522
# Epoch 36/100
# 9/9 [==============================] - 0s 12ms/step - loss: 23.7102 - mae: 3.4964 - val_loss: 49.9068 - val_mae: 4.8321
# Epoch 37/100
# 9/9 [==============================] - 0s 11ms/step - loss: 23.5278 - mae: 3.5108 - val_loss: 45.6115 - val_mae: 4.4108
# Epoch 38/100
# 9/9 [==============================] - 0s 12ms/step - loss: 23.6389 - mae: 3.5080 - val_loss: 48.6088 - val_mae: 4.6384
# Epoch 39/100
# 9/9 [==============================] - 0s 11ms/step - loss: 23.2142 - mae: 3.4715 - val_loss: 47.7778 - val_mae: 4.5480
# Epoch 40/100
# 9/9 [==============================] - 0s 9ms/step - loss: 23.1540 - mae: 3.4309 - val_loss: 45.9155 - val_mae: 4.4249
# Epoch 41/100
# 9/9 [==============================] - 0s 9ms/step - loss: 22.9433 - mae: 3.4044 - val_loss: 47.5570 - val_mae: 4.5180
# Epoch 42/100
# 9/9 [==============================] - 0s 7ms/step - loss: 22.5101 - mae: 3.4042 - val_loss: 50.9354 - val_mae: 4.7052
# Epoch 43/100
# 9/9 [==============================] - 0s 11ms/step - loss: 22.4858 - mae: 3.3664 - val_loss: 47.6514 - val_mae: 4.4759
# Epoch 44/100
# 9/9 [==============================] - 0s 10ms/step - loss: 22.9865 - mae: 3.4146 - val_loss: 48.9511 - val_mae: 4.6013
# Epoch 45/100
# 9/9 [==============================] - 0s 16ms/step - loss: 22.2577 - mae: 3.3325 - val_loss: 45.0339 - val_mae: 4.3252
# Epoch 46/100
# 9/9 [==============================] - 0s 13ms/step - loss: 22.5033 - mae: 3.3374 - val_loss: 47.8424 - val_mae: 4.4615
# Epoch 47/100
# 9/9 [==============================] - 0s 12ms/step - loss: 21.4728 - mae: 3.2088 - val_loss: 53.2748 - val_mae: 4.9658
# Epoch 48/100
# 9/9 [==============================] - 0s 12ms/step - loss: 23.2105 - mae: 3.4735 - val_loss: 50.2558 - val_mae: 4.6223
# Epoch 49/100
# 9/9 [==============================] - 0s 13ms/step - loss: 21.8071 - mae: 3.2857 - val_loss: 48.6988 - val_mae: 4.4911
# Epoch 50/100
# 9/9 [==============================] - 0s 11ms/step - loss: 21.9523 - mae: 3.3045 - val_loss: 47.7848 - val_mae: 4.4142
# Epoch 51/100
# 9/9 [==============================] - 0s 11ms/step - loss: 21.8929 - mae: 3.3033 - val_loss: 47.2381 - val_mae: 4.3841
# Epoch 52/100
# 9/9 [==============================] - 0s 12ms/step - loss: 22.1871 - mae: 3.3376 - val_loss: 50.4435 - val_mae: 4.5810
# Epoch 53/100
# 9/9 [==============================] - 0s 12ms/step - loss: 21.5004 - mae: 3.3118 - val_loss: 46.3228 - val_mae: 4.3539
# Epoch 54/100
# 9/9 [==============================] - 0s 13ms/step - loss: 21.7996 - mae: 3.3183 - val_loss: 50.7080 - val_mae: 4.5780
# Epoch 55/100
# 9/9 [==============================] - 0s 11ms/step - loss: 21.4038 - mae: 3.2503 - val_loss: 49.0896 - val_mae: 4.4979
# Epoch 56/100
# 9/9 [==============================] - 0s 9ms/step - loss: 21.6191 - mae: 3.2976 - val_loss: 51.3568 - val_mae: 4.6231
# Epoch 57/100
# 9/9 [==============================] - 0s 11ms/step - loss: 21.3719 - mae: 3.2674 - val_loss: 46.0084 - val_mae: 4.3019
# Epoch 58/100
# 9/9 [==============================] - 0s 10ms/step - loss: 21.9103 - mae: 3.2965 - val_loss: 47.3212 - val_mae: 4.3181
# Epoch 59/100
# 9/9 [==============================] - 0s 22ms/step - loss: 21.1374 - mae: 3.2028 - val_loss: 46.1503 - val_mae: 4.2438
# Epoch 60/100
# 9/9 [==============================] - 0s 9ms/step - loss: 21.0463 - mae: 3.1903 - val_loss: 47.5324 - val_mae: 4.3257
# Epoch 61/100
# 9/9 [==============================] - 0s 11ms/step - loss: 21.3763 - mae: 3.2542 - val_loss: 47.6389 - val_mae: 4.3464
# Epoch 62/100
# 9/9 [==============================] - 0s 10ms/step - loss: 21.6563 - mae: 3.2658 - val_loss: 46.5836 - val_mae: 4.3177
# Epoch 63/100
# 9/9 [==============================] - 0s 11ms/step - loss: 20.6719 - mae: 3.1728 - val_loss: 52.7193 - val_mae: 4.7803
# Epoch 64/100
# 9/9 [==============================] - 0s 12ms/step - loss: 21.3809 - mae: 3.2563 - val_loss: 48.4756 - val_mae: 4.4246
# Epoch 65/100
# 9/9 [==============================] - 0s 11ms/step - loss: 20.8390 - mae: 3.1991 - val_loss: 49.0302 - val_mae: 4.4797
# Epoch 66/100
# 9/9 [==============================] - 0s 14ms/step - loss: 20.5933 - mae: 3.1880 - val_loss: 50.7303 - val_mae: 4.5389
# Epoch 67/100
# 9/9 [==============================] - 0s 13ms/step - loss: 20.6844 - mae: 3.1737 - val_loss: 51.0037 - val_mae: 4.5717
# Epoch 68/100
# 9/9 [==============================] - 0s 14ms/step - loss: 21.2417 - mae: 3.2221 - val_loss: 49.6514 - val_mae: 4.4380
# Epoch 69/100
# 9/9 [==============================] - 0s 13ms/step - loss: 20.5984 - mae: 3.1475 - val_loss: 47.1799 - val_mae: 4.2913
# Epoch 70/100
# 9/9 [==============================] - 0s 14ms/step - loss: 20.4499 - mae: 3.1227 - val_loss: 52.5198 - val_mae: 4.6720
# Epoch 71/100
# 9/9 [==============================] - 0s 16ms/step - loss: 20.3950 - mae: 3.1549 - val_loss: 47.9011 - val_mae: 4.3843
# Epoch 72/100
# 9/9 [==============================] - 0s 16ms/step - loss: 20.8748 - mae: 3.2107 - val_loss: 46.5794 - val_mae: 4.2535
# Epoch 73/100
# 9/9 [==============================] - 0s 11ms/step - loss: 20.1565 - mae: 3.1071 - val_loss: 53.5518 - val_mae: 4.7050
# Epoch 74/100
# 9/9 [==============================] - 0s 10ms/step - loss: 20.7016 - mae: 3.2344 - val_loss: 50.7019 - val_mae: 4.6057
# Epoch 75/100
# 9/9 [==============================] - 0s 8ms/step - loss: 20.2039 - mae: 3.1090 - val_loss: 52.0744 - val_mae: 4.5987
# Epoch 76/100
# 9/9 [==============================] - 0s 13ms/step - loss: 20.5488 - mae: 3.1369 - val_loss: 50.9093 - val_mae: 4.5313
# Epoch 77/100
# 9/9 [==============================] - 0s 23ms/step - loss: 20.3819 - mae: 3.1583 - val_loss: 48.3891 - val_mae: 4.4359
# Epoch 78/100
# 9/9 [==============================] - 0s 21ms/step - loss: 20.5483 - mae: 3.1601 - val_loss: 55.1140 - val_mae: 4.9000
# Epoch 79/100
# 9/9 [==============================] - 0s 27ms/step - loss: 21.4518 - mae: 3.2746 - val_loss: 47.2968 - val_mae: 4.3410
# Epoch 80/100
# 9/9 [==============================] - 0s 24ms/step - loss: 19.9014 - mae: 3.1363 - val_loss: 49.0621 - val_mae: 4.3771
# Epoch 81/100
# 9/9 [==============================] - 0s 28ms/step - loss: 20.2114 - mae: 3.1377 - val_loss: 46.4796 - val_mae: 4.2324
# Epoch 82/100
# 9/9 [==============================] - 0s 22ms/step - loss: 20.0790 - mae: 3.0961 - val_loss: 49.9117 - val_mae: 4.5717
# Epoch 83/100
# 9/9 [==============================] - 0s 30ms/step - loss: 20.3913 - mae: 3.1841 - val_loss: 51.9487 - val_mae: 4.5869
# Epoch 84/100
# 9/9 [==============================] - 0s 31ms/step - loss: 20.4530 - mae: 3.1631 - val_loss: 54.8818 - val_mae: 4.9714
# Epoch 85/100
# 9/9 [==============================] - 0s 27ms/step - loss: 20.6139 - mae: 3.2318 - val_loss: 47.7352 - val_mae: 4.3507
# Epoch 86/100
# 9/9 [==============================] - 0s 32ms/step - loss: 20.5435 - mae: 3.1356 - val_loss: 48.5373 - val_mae: 4.3667
# Epoch 87/100
# 9/9 [==============================] - 0s 37ms/step - loss: 20.0831 - mae: 3.0829 - val_loss: 50.3113 - val_mae: 4.4673
# Epoch 88/100
# 9/9 [==============================] - 0s 34ms/step - loss: 20.4045 - mae: 3.1010 - val_loss: 53.3279 - val_mae: 4.7665
# Epoch 89/100
# 9/9 [==============================] - 0s 22ms/step - loss: 20.2297 - mae: 3.1303 - val_loss: 50.4738 - val_mae: 4.5260
# Epoch 90/100
# 9/9 [==============================] - 0s 29ms/step - loss: 19.8878 - mae: 3.1116 - val_loss: 48.2259 - val_mae: 4.3764
# Epoch 91/100
# 9/9 [==============================] - 0s 22ms/step - loss: 21.1554 - mae: 3.2405 - val_loss: 48.2486 - val_mae: 4.4387
# Epoch 92/100
# 9/9 [==============================] - 0s 20ms/step - loss: 20.3655 - mae: 3.1405 - val_loss: 47.1013 - val_mae: 4.2992
# Epoch 93/100
# 9/9 [==============================] - 0s 24ms/step - loss: 20.0344 - mae: 3.1514 - val_loss: 53.5129 - val_mae: 4.8065
# Epoch 94/100
# 9/9 [==============================] - 0s 17ms/step - loss: 21.1216 - mae: 3.2047 - val_loss: 51.3082 - val_mae: 4.5776
# Epoch 95/100
# 9/9 [==============================] - 0s 14ms/step - loss: 19.8343 - mae: 3.0475 - val_loss: 53.0311 - val_mae: 4.8257
# Epoch 96/100
# 9/9 [==============================] - 0s 10ms/step - loss: 20.0955 - mae: 3.0222 - val_loss: 46.9193 - val_mae: 4.2813
# Epoch 97/100
# 9/9 [==============================] - 0s 7ms/step - loss: 20.5678 - mae: 3.2064 - val_loss: 46.3194 - val_mae: 4.2469
# Epoch 98/100
# 9/9 [==============================] - 0s 6ms/step - loss: 19.8773 - mae: 3.0998 - val_loss: 49.0444 - val_mae: 4.4026
# Epoch 99/100
# 9/9 [==============================] - 0s 8ms/step - loss: 20.1109 - mae: 3.1132 - val_loss: 46.3228 - val_mae: 4.1980
# Epoch 100/100
# 9/9 [==============================] - 0s 8ms/step - loss: 20.0306 - mae: 3.0981 - val_loss: 52.1572 - val_mae: 4.5941
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 128)               640
#
#  dense_11 (Dense)            (None, 64)                8256
#
#  dense_12 (Dense)            (None, 32)                2080
#
#  dense_13 (Dense)            (None, 16)                528
#
#  dense_14 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 11521 (45.00 KB)
# Trainable params: 11521 (45.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
test_mse_score, test_mae_score = model.evaluate(X_test, y_test)
print('Error cuadrático medio en el conjunto de prueba:', test_mse_score)
print('Error absoluto medio en el conjunto de prueba:', test_mae_score)
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 74.8676 - mae: 5.0421
# Error cuadrático medio en el conjunto de prueba: 74.86760711669922
# Error absoluto medio en el conjunto de prueba: 5.04214334487915

# %%
# Graficar el loss del conjunto de entrenamiento y de validación
plt.plot(fit.history['loss'], 'b', label='train')
plt.plot(fit.history['val_loss'], 'r--', label='val')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()

# %%
# Graficar el loss del conjunto de entrenamiento y de validación
plt.plot(fit.history['loss'], 'b', label='train')
plt.plot(fit.history['val_loss'], 'r--', label='val')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()

# %%
predicted = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
predicted.shape, test_data.shape
# Out:
# ((102, 1), (102, 12))

# %%
plt.figure(figsize=(10, 5))
plt.plot(predicted, 'r*-', label='Prediction')
plt.plot(y_test.values, 'bo-', label='Test Labels')
plt.xlabel('Index')
plt.ylabel('MEDV')
plt.legend()
plt.show()

# %% [markdown]
# **Código de solución estudiante 2 Rafael Juarez**

# %%
(train_data, train_labels), (test_data, test_labels) = keras.datasets.boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 [==============================] - 0s 0us/step

# %%
train_data.shape, test_data.shape
# Out:
# ((404, 13), (102, 13))

# %%
# Analizar la data completa
columns = [
    'CRIM',
    'ZN',
    'INDUS',
    'CHAS',
    'NOX',
    'RM',
    'AGE',
    'DIS',
    'RAD',
    'TAX',
    'PTRATIO',
    'B',
    'LSTAT',
    'MEDV',
]

X = np.vstack([train_data, test_data])
y = np.hstack([train_labels, test_labels]).reshape(-1, 1)
data = pd.DataFrame(np.concatenate((X, y), axis=1), columns=columns)
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0    1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1    0.02177  82.5   2.03   0.0  0.415  7.610   15.7  6.2700   2.0  348.0
# 2    4.89822   0.0  18.10   0.0  0.631  4.970  100.0  1.3325  24.0  666.0
# 3    0.03961   0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 4    3.69311   0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
# ..       ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 501  3.47428   0.0  18.10   1.0  0.718  8.780   82.9  1.9047  24.0  666.0
# 502  0.07896   0.0  12.83   0.0  0.437  6.273    6.0  4.2515   5.0  398.0
# 503  1.83377   0.0  19.58   1.0  0.605  7.802   98.2  2.0407   5.0  403.0
# 504  0.35809   0.0   6.20   1.0  0.507  6.951   88.5  2.8617   8.0  307.0
# 505  2.92400   0.0  19.58   0.0  0.605  6.101   93.0  2.2834   5.0  403.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       21.0  396.90  18.72  15.2
# 1       14.7  395.38   3.11  42.3
# 2       20.2  375.52   3.26  50.0
# 3       20.2  396.90   8.01  21.1
# 4       20.2  391.43  14.65  17.7
# ..       ...     ...    ...   ...
# 501     20.2  354.55   5.29  21.9
# 502     18.7  394.92   6.78  24.1
# 503     14.7  389.61   1.92  50.0
# 504     17.4  391.70   9.71  26.7
# 505     14.7  240.16   9.81  25.0
#
# [506 rows x 14 columns]

# %%
import seaborn as sn
sn.displot(data, x='MEDV', kde=True)

# %%
corr = data.corr().round(2)

fig, ax = plt.subplots(1,1, figsize=(10, 8))
sn.heatmap(corr, annot=True, ax=ax)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,7))
plt.boxplot(data)
plt.show()

# %%
output_col = ['MEDV']
data[output_col].plot()
# Out:
# <Axes: >

# %%
TEST_SIZE = int(0.2 * data.shape[0])
TRAIN_SIZE = data.shape[0] - TEST_SIZE

t = np.arange(1, X.shape[0] + 1)
train_data, test_data = X[:TRAIN_SIZE], X[TRAIN_SIZE:]
train_labels, test_labels = y[:TRAIN_SIZE], y[TRAIN_SIZE:]

fig, ax = plt.subplots(1,2, figsize=(10,5))
ax[0].plot(t[:TRAIN_SIZE], train_data, 'r*-', label='train data')
ax[0].plot(t[TRAIN_SIZE:], test_data, 'bo-', label='test data')
ax[0].legend()

ax[1].plot(t[:TRAIN_SIZE], train_labels, 'r*-', label='train labels')
ax[1].plot(t[TRAIN_SIZE:], test_labels, 'bo-', label='test labels')
plt.legend()

# %%
test_data.shape, test_labels.shape
# Out:
# ((101, 13), (101, 1))

# %%
mean = train_data.mean(axis=0)
std = train_data.std(axis=0)
train_data = (train_data - mean) / std
test_data = (test_data - mean) / std

# %%
tf.random.set_seed(17)

model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(train_data.shape[1],)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1)
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 64)                896
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dense_6 (Dense)             (None, 16)                1040
#
#  dense_7 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 6113 (23.88 KB)
# Trainable params: 6113 (23.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model_fit = model.fit(
    train_data, train_labels, 
    validation_split=0.2, 
    shuffle=False,
    epochs=50, 
    batch_size=32, 
    verbose=0
)

test_mse_score, test_mae_score = model.evaluate(test_data, test_labels)
print('Cuadratic mean error:', test_mse_score)
print('Mean absolute error:', test_mae_score)
# Out:
# 2024-03-07 16:21:06.833764: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-03-07 16:21:19.710706: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f2de5e46530 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-03-07 16:21:19.710812: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Ti Laptop GPU, Compute Capability 8.6
# 2024-03-07 16:21:19.942955: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-03-07 16:21:23.109521: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709850085.016700   75750 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4/4 [==============================] - 0s 11ms/step - loss: 29.6429 - mae: 3.3826
# Cuadratic mean error: 29.642892837524414
# Mean absolute error: 3.3825695514678955

# %%
plt.plot(model_fit.history['loss'], 'b', label='train')
plt.plot(model_fit.history['val_loss'], 'r--', label='val')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()

# %%
plt.plot(model_fit.history['mae'], 'b', label='train')
plt.plot(model_fit.history['val_mae'], 'r--', label='val')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend()

# %%
predicted = model.predict(test_data)
# Out:
# 4/4 [==============================] - 0s 5ms/step

# %%
plt.figure(figsize=(10,5))
plt.plot(t[TRAIN_SIZE:], predicted, 'r*-', label='prediction')
plt.plot(t[TRAIN_SIZE:], test_labels, 'bo-', label='test labels')

plt.legend()
